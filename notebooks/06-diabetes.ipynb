# %% [markdown]
# # 6. Etude du jeu de données Diabetes
#
# Nous allons étudier un problème de regression sur un jeu de données de patients atteints de diabète. Nous utiliserons un jeu de données qui décrit 442 patients souffrant de diabète. Il s'agit de prédire l'évolution de la maladie au bout d'un an :

# %%
from sklearn import datasets

diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes.data)
df.columns = diabetes.feature_names
df["target"] = diabetes.target

# %%
print(diabetes.DESCR)

# %% [markdown]
# ## Analyse exploratoire des données
#
# Réalisez une analyse exploratoire de ce dataset, pour vous aider vous pouvez répondre aux questions suivantes :
# * Quels sont les types de variables du dataset ?
# * Quelles sont les modalités des variables qualitatives ? (aka : catégorielles)
# * Quels sont les moyennes, écarts types, min, max ... des variables numériques ?
# * Existe-t'il des corrélations fortes entre ces variables numériques ?
#
# Vous pouvez aussi afficher certains graphiques avec matplotlib, seaborn ou plotly. Par exemple : [`sns.distplot`](https://seaborn.pydata.org/generated/seaborn.distplot.html), [`sns.boxplot`](https://seaborn.pydata.org/generated/seaborn.boxplot.html) ou encore [`sns.heatmap`](https://seaborn.pydata.org/generated/seaborn.heatmap.html).
#
# Pensez aussi à regarder certains individus de ce dataset (pas seulement des informations statistiques).

# %% [markdown]
# ## Construction du jeu d'entraînement et du jeu de test
#
# Nous devons sans tarder réserver un jeu de test... Sinon, nous serons incapables de mesurer la capacité de notre modèle à généraliser, c'est-à-dire à prédire sur de nouvelles données. Pour cela utilisez la fonction [`sklearn.model_selection.train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) en réservant 20% du dataset pour notre jeu de test :

# %% [markdown]
# Avant de construire les modèles prédictifs, il convient de séparer les variables de la cible à prédire. construisez une dataframe `X_tain` et `X_test` contenant notre jeu de donnée sans la cible. De même construisez `y_train` et `y_test` ne contenant que la cible :

# %% [markdown]
# ## Exploration des modèles
#
# Entrainez et vérifier les performances d'un modèle de régression linéaire sur le jeu de test :

# %% [markdown]
# ## Validation croisée
#
# Evaluez la performance (la moyenne et l'écart type de la RMSE) d'un modèle linéaire simple au moyen d'une validation croisée à 10 plis sur le dataset d'entrainement en utilisant la fonction [`sklearn.model_selection.cross_val_score`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html). La méthode de `scoring` MSE disponible pour cette fonction est `neg_mean_absolute_error` (qui fournit des valeurs négatives, pensez à la rendre positive) :

# %% [markdown]
# ## Optimisation des hyper-paramètres
#
# Trouvez le meilleur coefficient de régularisation de modèles de régression LASSO et RIDGE avec une validation croisée à 5 plis sur le dataset d'entrainement en utilisant la classe [`sklearn.model_selection.GridSearchCV`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Quel sont les meilleurs coefficients de régularisation pour ces deux méthodes ? Quel est le RMSE sur le dataset de test ?

# %% [markdown]
# ## Autre modèles
#
# Testez et comparez les modèles suivants avec les modèles précédents (pensez à recherchez les meilleurs hyper-paramètres :
# * [`sklearn.linear_model.ElasticNet`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html)
# * [`sklearn.ensemble.RandomForestRegressor`](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
